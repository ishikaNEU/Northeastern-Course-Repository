# %%
# scraping: https://www.northeastern.edu/graduate/?s=data+analytics&paged=1

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import itertools
import re

# %%
program=[]
base_url='https://www.northeastern.edu/graduate/?s=master&paged={}'

for n in range(1,30):
    scrape_url=base_url.format(n)
    res=requests.get(scrape_url)

    soup=bs(res.text, 'lxml')
    courses=soup.select('.program-title')
    duration=soup.select('.col-3')
    location=soup.select('.col-1')
    
    for loc, year, course in zip(location, duration, courses): 
        course_title=course.select('a')[0] 
        course_duration=list(year.select('nobr'))
        course_location=list(loc.select('h5'))
        
        if len(course_location)==1:
            program.append([course_title.text, course_duration[0].text,course_location[0].text ,course_title['href']])
    
programdf = pd.DataFrame(program,columns = ["Program Name","Duration",'loc', "Program Link"])

programdf=programdf.drop('loc', axis=1)

programdf.drop_duplicates(subset="Program Name", keep="first", inplace=True)
programdf
# Out:
#                                        Program Name       Duration  \
# 0                                     Cybersecurity      2-3 Years
# 1                                    Bioengineering    2-2.5 years
# 2                                Health Informatics        2 Years
# 3                                  Computer Science      2-3 Years
# 4               Electrical and Computer Engineering   18-24 Months
# ..                                              ...            ...
# 117  Organizational Leadership/1-Year Experiential       1-2 years
# 119                                        Robotics        2 Years
# 121              Insurance Analytics and Management    2.5-3 Years
# 122                   Applied Machine Intelligence     2.5-3 Years
# 123                                   Public Health  12-18 Months
#
#                                           Program Link
# 0    https://www.northeastern.edu/graduate/program/...
# 1    https://www.northeastern.edu/graduate/program/...
# 2    https://www.northeastern.edu/graduate/program/...
# 3    https://www.northeastern.edu/graduate/program/...
# 4    https://www.northeastern.edu/graduate/program/...
# ..                                                 ...
# 117  https://www.northeastern.edu/graduate/program/...
# 119  https://www.northeastern.edu/graduate/program/...
# 121  https://www.northeastern.edu/graduate/program/...
# 122  https://www.northeastern.edu/graduate/program/...
# 123  https://www.northeastern.edu/graduate/program/...
#
# [99 rows x 3 columns]

# %%
import mysql.connector
neucourse = mysql.connector.connect(host = 'localhost', user = 'root',passwd = 'Sundaram@123', database = 'dmdd_proj_neu_course')
mycursor = neucourse.cursor()

# %%
for i,row in programdf.iterrows():
    sql = "INSERT INTO dmdd_proj_neu_course.neu_program (program_name,duration,program_url) values(%s,%s,%s)"
    mycursor.execute(sql,tuple(row))
    neucourse.commit()
print("Records inserted")
# Out:
# Records inserted

# %%
# scraping https://catalog.northeastern.edu/course-descriptions/****/ for DAMG/INFO/CSYE

# %%
course_catalog=[]
url_damg='https://catalog.northeastern.edu/course-descriptions/damg/'

result_damg=requests.get(url_damg)
soup_catalog_damg=bs(result_damg.text,'lxml')
catalog_damg=soup_catalog_damg.select(".courseblock")

for course in catalog_damg:
    
    course_id=course.select('.courseblocktitle')[0]
    course_description=course.select('.cb_desc')[0]
    
    c_id=re.search(r'\d\d\d\d', course_id.text)
    damg_id='DAMG '+ str(c_id.group())
    damg_name=course_id.text[12:]
        
    course_catalog.append(['Data Analytics Engineering',damg_id, damg_name,course_description.text])
    
    
url_info='https://catalog.northeastern.edu/course-descriptions/info/'

result_info=requests.get(url_info)
soup_catalog_info=bs(result_info.text,'lxml')
catalog_info=soup_catalog_info.select(".courseblock")

for course in catalog_info:
    
    course_id=course.select('.courseblocktitle')[0]
    course_description=course.select('.cb_desc')[0]
    
    c_id=re.search(r'\d\d\d\d', course_id.text)
    info_id='INFO '+ str(c_id.group())
    info_name=course_id.text[12:]
        
    course_catalog.append(['Information Systems',info_id, info_name,course_description.text])

url_csye='https://catalog.northeastern.edu/course-descriptions/csye/'

course_catalog_csye=[]

result_csye=requests.get(url_csye)
soup_catalog_csye=bs(result_csye.text,'lxml')
catalog_csye=soup_catalog_csye.select(".courseblock")

for course in catalog_csye:
    
    course_id=course.select('.courseblocktitle')[0]
    course_description=course.select('.cb_desc')[0]
    
    c_id=re.search(r'\d\d\d\d', course_id.text)
    csye_id='CSYE '+ str(c_id.group())
    csye_name=course_id.text[12:]
        
    course_catalog.append(['Software Engineering Systems', csye_id, csye_name,course_description.text])

# %%
catalogdf = pd.DataFrame(course_catalog,columns = ["Program_name","Course ID","Course_Name", "Description"])
catalogdf.drop_duplicates(subset="Course ID", keep="first", inplace=True)
catalogdf
# Out:
#                     Program_name  Course ID  \
# 0     Data Analytics Engineering  DAMG 6105
# 1     Data Analytics Engineering  DAMG 6210
# 2     Data Analytics Engineering  DAMG 7105
# 3     Data Analytics Engineering  DAMG 7245
# 4     Data Analytics Engineering  DAMG 7250
# ..                           ...        ...
# 75  Software Engineering Systems  CSYE 7550
# 76  Software Engineering Systems  CSYE 7962
# 77  Software Engineering Systems  CSYE 7978
# 78  Software Engineering Systems  CSYE 7990
# 79  Software Engineering Systems  CSYE 7996
#
#                                           Course_Name  \
# 0    Data Science Engineering with Python.  (4 Hours)
# 1     Data Management and Database Design.  (4 Hours)
# 2   Intelligent Data Modeling and Presentation for...
# 3   Big-Data Systems and Intelligence Analytics.  ...
# 4    Big Data Architecture and Governance.  (4 Hours)
# ..                                                ...
# 75  Distributed Intelligent Agents in the Metavers...
# 76                             Elective.  (1-4 Hours)
# 77                    Independent Study.  (1-4 Hours)
# 78                               Thesis.  (1-8 Hours)
# 79                    Thesis Continuation.  (0 Hours)
#
#                                           Description
# 0   Studies the Python programming language with d...
# 1   Studies design of information systems from a d...
# 2   Studies every step in a data analysis pipeline...
# 3   Offers students an opportunity to learn a hand...
# 4   Focuses on creating and managing a data-driven...
# ..                                                ...
# 75  Introduces the field of agent-based computing ...
# 76  Offers elective credit for courses taken at ot...
# 77  Offers theoretical or experimental work under ...
# 78  Offers analytical and/or experimental work con...
# 79  Offers analytical and/or experimental work con...
#
# [80 rows x 4 columns]

# %%
import mysql.connector
neucourse = mysql.connector.connect(host = 'localhost', user = 'root',passwd = 'Sundaram@123', database = 'dmdd_proj_neu_course')
mycursor = neucourse.cursor()

# %%
for i,row in catalogdf.iterrows():
    sql = "INSERT INTO dmdd_proj_neu_course.neu_course_catalog (program_name,course_id,course_name,course_description) values(%s,%s,%s,%s)"
    mycursor.execute(sql,tuple(row))
    neucourse.commit()
print("Records inserted")
# Out:
# Records inserted

# %%
import pandas as pd

# %%
df = pd.read_csv('Resource_material.csv',
                usecols = ['Please select the course id for above course.',
       'Please provide website url for the above software download',
       'Which Professional Certifications are available to master skills for this course?',
       'Which online platform is available  to practice/study the course?',
       'Course Rating ', 'ResourceType'])

# %%
df.head()
# Out:
#   Please select the course id for above course.  \
# 0                                     INFO 6106
# 1                                     DAMG 6105
# 2                                     CSYE 6225
# 3                                     INFO 5002
# 4                                     INFO 6205
#
#   Please provide website url for the above software download  \
# 0           https://neural-designer.en.softonic.com/
# 1                  https://www.python.org/downloads/
# 2       https://azure.microsoft.com/en-us/downloads/
# 3                  https://www.python.org/downloads/
# 4                https://visualstudio.microsoft.com/
#
#   Which Professional Certifications are available to master skills for this course?  \
# 0   Azure AI Engineer Associate: Certificate from...
# 1     Certified Professional in Python Programming 1
# 2                AZ-900 Microsoft Azure Fundamentals
# 3      PCEP: Certified Entry-Level Python Programmer
# 4  https://www.udemy.com/course/c-sharp-visual-st...
#
#   Which online platform is available  to practice/study the course?  \
# 0  https://playground.tensorflow.org/#activation=...
# 1                     https://www.online-python.com/
# 2                 https://www.cloudzero.com/platform
# 3                     https://www.online-python.com/
# 4                                              Udemy
#
#    Course Rating  ResourceType
# 0               4         Free
# 1               3         Free
# 2               5         Paid
# 3               3         Free
# 4               4         Free

# %%
import mysql.connector
neucourse = mysql.connector.connect(host = 'localhost', user = 'root',passwd = 'Sundaram@123', database = 'dmdd_proj_neu_course')
mycursor = neucourse.cursor()

# %%
for i,row in df.iterrows():
    sql = "INSERT INTO dmdd_proj_neu_course.resource_material1(course_id,software_download_url,professional_certificate,online_platform,course_rating,resource_type) values (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql,tuple(row))
    neucourse.commit()
print("Records inserted")
# Out:
# Records inserted

# %%
# Reading faculty details from Google response sheet

# %%
faculty = pd.read_csv('Faculty.csv',
                usecols = ['Which Program did you take in Northeastern?',
                          'Which course did you completed?',
                          'Under Which professor did you choose your course?',
                          'Rate the professor'])

# %%
faculty.head ()
# Out:
#   Which Program did you take in Northeastern? Which course did you completed?  \
# 0                         Information Systems                       INFO 5100
# 1                  Data Analytics Engineering                       DAMG 6105
# 2                  Data Analytics Engineering                       DAMG 7350
# 3                         Information Systems                       INFO 6105
# 4                Software Engineering Systems                       CSYE 6305
#
#   Under Which professor did you choose your course?  Rate the professor
# 0                               Prof Khaled Bugrara                   4
# 1                                   Prof Nick Brown                   4
# 2                                    Nick Beauchamp                   4
# 3                                    Nik Bear Brown                   5
# 4                             Prof. Hossein Noorian                   3

# %%
import mysql.connector
neucourse = mysql.connector.connect(host = 'localhost', user = 'root',passwd = 'Sundaram@123', database = 'dmdd_proj_neu_course')
mycursor = neucourse.cursor()

# %%
for i,row in faculty.iterrows():
    sql = "INSERT INTO dmdd_proj_neu_course.NEU_Course_Faculty (program_name,course_id,faculty_name,faculty_rating) values(%s,%s,%s,%s)"
    mycursor.execute(sql,tuple(row))
    neucourse.commit()
print("Records inserted")
# Out:
# Records inserted

# %%
# Scrape data for finding core_course_requirements

# %%
# importing the libraries
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd


urls=['https://catalog.northeastern.edu/graduate/engineering/multidisciplinary/information-systems-msis/#programrequirementstext','https://catalog.northeastern.edu/graduate/engineering/multidisciplinary/software-engineering-systems-ms/#programrequirementstext','https://catalog.northeastern.edu/graduate/engineering/mechanical-industrial/data-analytics-engineering-ms/#programrequirementstext']

program_name = {'https://catalog.northeastern.edu/graduate/engineering/multidisciplinary/information-systems-msis/#programrequirementstext': 'Information Systems', 'https://catalog.northeastern.edu/graduate/engineering/multidisciplinary/software-engineering-systems-ms/#programrequirementstext': 'Software Engineering Systems', 'https://catalog.northeastern.edu/graduate/engineering/mechanical-industrial/data-analytics-engineering-ms/#programrequirementstext': 'Data Analytics Engineering'}

tableValues=[]

for url in urls:
    core_course=[]
    result=requests.get(url)
    soup=bs(result.text,'html.parser')
    core_course_catalog=soup.select(".sc_courselist")


    myTable = soup.find('table',{'class':"sc_courselist"})

    row_headers = []
    for x in myTable.find_all('tr'):
        for y in x.find_all('th'):
            row_headers.append(y.text)


    for x in myTable.find_all('tr')[1:]:
        td_tags = x.find_all('td')
        td_val = [program_name[url]]+[y.text for y in td_tags]
        tableValues.append(td_val)
    
df=pd.DataFrame(tableValues,columns=['Program Name','Course ID','Course Name','Credit Hours'])

df=df.drop('Credit Hours', axis=1)
df
# Out:
#                    Program Name               Course ID  \
# 0           Information Systems  INFO 5100and INFO 5101
# 1  Software Engineering Systems               CSYE 6200
# 2  Software Engineering Systems               INFO 6205
# 3    Data Analytics Engineering                 IE 5374
# 4    Data Analytics Engineering                 IE 6600
# 5    Data Analytics Engineering                 IE 6700
# 6    Data Analytics Engineering            or DAMG 6210
# 7    Data Analytics Engineering                 IE 7275
# 8    Data Analytics Engineering                 IE 7280
# 9    Data Analytics Engineering                 OR 6205
#
#                                          Course Name
# 0  Application Engineering and Developmentand Lab...
# 1                 Concepts of Object-Oriented Design
# 2                   Program Structure and Algorithms
# 3           Special Topics in Industrial Engineering
# 4        Computation and Visualization for Analytics
# 5                      Data Management for Analytics
# 6                Data Management and Database Design
# 7                         Data Mining in Engineering
# 8                 Statistical Methods in Engineering
# 9                  Deterministic Operations Research

# %%
import mysql.connector
neucourse = mysql.connector.connect(host = 'localhost', user = 'root',passwd = 'Sundaram@123', database = 'dmdd_proj_neu_course')
mycursor = neucourse.cursor()

# %%
for i,row in df.iterrows():
    sql = "INSERT INTO dmdd_proj_neu_course.course_core_requirement (program_name,course_id,course_name) values (%s,%s,%s)"
    mycursor.execute(sql,tuple(row))
    neucourse.commit()
print("Records inserted")
# Out:
# Records inserted

# %%
#import pandas as pd
#df = pd.DataFrame(pd.read_json("C:\\Users\\utkar\\OneDrive\\Desktop\\SEM 1\\Java\\Java_Assignments\\linkedinbot\\linkedinbot\\spiders\\data\\linkedinSpider_2022-12-01T04-41-04.json"))
#df

# %%
#create dataframe for jobs

# %%
df_SES = pd.DataFrame(pd.read_json("C:\\Users\\utkar\\OneDrive\\Desktop\\SEM 1\\Java\\Java_Assignments\\linkedinbot\\linkedinbot\\spiders\\data\\linkedinSpider_2022-12-03T22-03-06.json"))
df_IS = pd.DataFrame(pd.read_json("C:\\Users\\utkar\\OneDrive\\Desktop\\SEM 1\\Java\\Java_Assignments\\linkedinbot\\linkedinbot\\spiders\\data\\linkedinSpider_2022-12-03T22-07-03.json"))
df_DAE = pd.DataFrame(pd.read_json("C:\\Users\\utkar\\OneDrive\\Desktop\\SEM 1\\Java\\Java_Assignments\\linkedinbot\\linkedinbot\\spiders\\data\\linkedinSpider_2022-12-03T22-10-03.json"))
df=pd.concat([df_SES, df_IS, df_DAE])
df
# Out:
#                      programName  \
# 0     Data Analytics Engineering
# 1     Data Analytics Engineering
# 2     Data Analytics Engineering
# 3     Data Analytics Engineering
# 4     Data Analytics Engineering
# ..                           ...
# 45  Software Engineering Systems
# 46  Software Engineering Systems
# 47  Software Engineering Systems
# 48  Software Engineering Systems
# 49  Software Engineering Systems
#
#                                                 title       jobId  \
# 0           Associate, Content Analytics & Operations  3356615002
# 1         Principal Analyst, Data Science & Analytics  3311157304
# 2                                  VP, Data Analytics  3339080809
# 3           Vice President – Data Science & Analytics  3219049068
# 4                                  VP, Data Analytics  3343511133
# ..                                                ...         ...
# 45  Vice President, System Operations and Infrastr...  3379639408
# 46                    Information Technology Engineer  3385840807
# 47                    Software Dev Engineering Intern  3385766806
# 48                                  Systems Developer  3385236440
# 49                                   Systems Engineer  3380821988
#
#                  companyName           location  datePosted  \
# 0                    Netflix    Los Angeles, CA  2022-11-16
# 1                     Zillow      United States  2022-11-23
# 2               TechInsights         Denver, CO  2022-11-01
# 3                  H&R Block      United States  2022-11-28
# 4   Propio Language Services  Overland Park, KS  2022-11-08
# ..                       ...                ...         ...
# 45          Raintree Systems      United States  2022-11-29
# 46    Outsource IT Solutions     Naperville, IL        None
# 47                     Yahoo      United States        None
# 48                     Ralco       Marshall, MN  2022-11-08
# 49                     Qrypt     Germantown, MD  2022-11-30
#
#                                                  link  \
# 0   https://www.linkedin.com/jobs/view/associate-c...
# 1   https://www.linkedin.com/jobs/view/principal-a...
# 2   https://www.linkedin.com/jobs/view/vp-data-ana...
# 3   https://www.linkedin.com/jobs/view/vice-presid...
# 4   https://www.linkedin.com/jobs/view/vp-data-ana...
# ..                                                ...
# 45  https://www.linkedin.com/jobs/view/vice-presid...
# 46  https://www.linkedin.com/jobs/view/information...
# 47  https://www.linkedin.com/jobs/view/software-de...
# 48  https://www.linkedin.com/jobs/view/systems-dev...
# 49  https://www.linkedin.com/jobs/view/systems-eng...
#
#                                           description    seniorityLevel  \
# 0   Netflix is the world's leading streaming enter...    Not Applicable
# 1   About The Team The Zillow Analytics organizati...  Mid-Senior level
# 2   OUR STORY TechInsights is the world’s most tru...          Director
# 3   What You'll Do... H&R Block is seeking a Vice ...         Executive
# 4   At  Propio Language Services  we are closing t...         Executive
# ..                                                ...               ...
# 45  As VP of Systems Operations & Infrastructure f...          Director
# 46  We are looking for a dedicated and dynamic ind...       Entry level
# 47  It takes powerful technology to connect our br...        Internship
# 48  Company Overview Ralco is a science and techno...  Mid-Senior level
# 49  Qrypt builds quantum-secure encryption softwar...  Mid-Senior level
#
#    employmentType                             jobFunction  \
# 0       Full-time            Management and Manufacturing
# 1       Full-time                 Engineering and Science
# 2       Full-time          Business Development and Sales
# 3       Full-time                                Research
# 4       Full-time          Business Development and Sales
# ..            ...                                     ...
# 45      Full-time                  Information Technology
# 46      Full-time  Engineering and Information Technology
# 47      Full-time  Engineering and Information Technology
# 48      Full-time  Engineering and Information Technology
# 49      Full-time                  Information Technology
#
#                                              industry
# 0   Movies, Videos, and Sound, Technology, Informa...
# 1                                Software Development
# 2                                 Internet Publishing
# 3                       Financial Services and Retail
# 4                        Translation and Localization
# ..                                                ...
# 45                                Internet Publishing
# 46                      IT Services and IT Consulting
# 47                               Advertising Services
# 48                                Internet Publishing
# 49                                Internet Publishing
#
# [150 rows x 12 columns]

# %%
import mysql.connector
neucourse = mysql.connector.connect(host = 'localhost', user = 'root',passwd = 'Sundaram@123', database = 'dmdd_proj_neu_course')
mycursor = neucourse.cursor()

# %%
for i,row in df.iterrows():
    sql = "INSERT INTO dmdd_proj_neu_course.jobs_info (program_name,title,job_id,company_name,location,date_posted,link,description,seniority_level,employement_type,job_function,industry) values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql,tuple(row))
    neucourse.commit()
print("Records inserted")
# Out:
# Records inserted
